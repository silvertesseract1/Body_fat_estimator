# %%
import pandas as pd
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pip install --upgrade joblib
# Out:
# Requirement already satisfied: joblib in c:\users\asus\anaconda3\lib\site-packages (1.3.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
df = pd.read_csv('bodyfat.csv')
df.head()
# Out:
#    Density  BodyFat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  Thigh  \
# 0   1.0708     12.3   23  154.25   67.75  36.2   93.1     85.2   94.5   59.0
# 1   1.0853      6.1   22  173.25   72.25  38.5   93.6     83.0   98.7   58.7
# 2   1.0414     25.3   22  154.00   66.25  34.0   95.8     87.9   99.2   59.6
# 3   1.0751     10.4   26  184.75   72.25  37.4  101.8     86.4  101.2   60.1
# 4   1.0340     28.7   24  184.25   71.25  34.4   97.3    100.0  101.9   63.2
#
#    Knee  Ankle  Biceps  Forearm  Wrist
# 0  37.3   21.9    32.0     27.4   17.1
# 1  37.3   23.4    30.5     28.9   18.2
# 2  38.9   24.0    28.8     25.2   16.6
# 3  37.3   22.8    32.4     29.4   18.2
# 4  42.2   24.0    32.2     27.7   17.7

# %%
## lets check the dataset have null values or not??
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 252 entries, 0 to 251
# Data columns (total 15 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Density  252 non-null    float64
#  1   BodyFat  252 non-null    float64
#  2   Age      252 non-null    int64
#  3   Weight   252 non-null    float64
#  4   Height   252 non-null    float64
#  5   Neck     252 non-null    float64
#  6   Chest    252 non-null    float64
#  7   Abdomen  252 non-null    float64
#  8   Hip      252 non-null    float64
#  9   Thigh    252 non-null    float64
#  10  Knee     252 non-null    float64
#  11  Ankle    252 non-null    float64
#  12  Biceps   252 non-null    float64
#  13  Forearm  252 non-null    float64
#  14  Wrist    252 non-null    float64
# dtypes: float64(14), int64(1)
# memory usage: 29.7 KB

# %%
def plotdistplots(col):

    plt.figure(figsize=(12,5))
    sn.distplot(df['BodyFat'],color='blue',hist=False,label='Bodyfat')
    sn.distplot(df[col],color = 'red', hist=False,label=col)
    plt.legend()
    plt.show()

cols = list(df.columns)
for i in cols:
    print(f'Distribuation plots for {i} feature is shown')
    plotdistplots(i)
    print("_"*100)
# Out:
# Distribuation plots for Density feature is shown
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_24668\555354685.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df['BodyFat'],color='blue',hist=False,label='Bodyfat')
# C:\Users\ASUS\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_24668\555354685.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df[col],color = 'red', hist=False,label=col)
# C:\Users\ASUS\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ____________________________________________________________________________________________________
# Distribuation plots for BodyFat feature is shown
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_24668\555354685.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df['BodyFat'],color='blue',hist=False,label='Bodyfat')
# C:\Users\ASUS\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_24668\555354685.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df[col],color = 'red', hist=False,label=col)
# C:\Users\ASUS\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ____________________________________________________________________________________________________
# Distribuation plots for Age feature is shown
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_24668\555354685.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df['BodyFat'],color='blue',hist=False,label='Bodyfat')
# C:\Users\ASUS\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_24668\555354685.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df[col],color = 'red', hist=False,label=col)
# C:\Users\ASUS\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ____________________________________________________________________________________________________
# Distribuation plots for Weight feature is shown
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_24668\555354685.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df['BodyFat'],color='blue',hist=False,label='Bodyfat')
# C:\Users\ASUS\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_24668\555354685.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df[col],color = 'red', hist=False,label=col)
# C:\Users\ASUS\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ____________________________________________________________________________________________________
# Distribuation plots for Height feature is shown
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_24668\555354685.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df['BodyFat'],color='blue',hist=False,label='Bodyfat')
# C:\Users\ASUS\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_24668\555354685.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df[col],color = 'red', hist=False,label=col)
# C:\Users\ASUS\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ____________________________________________________________________________________________________
# Distribuation plots for Neck feature is shown
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_24668\555354685.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df['BodyFat'],color='blue',hist=False,label='Bodyfat')
# C:\Users\ASUS\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_24668\555354685.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df[col],color = 'red', hist=False,label=col)
# C:\Users\ASUS\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_24668\555354685.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df['BodyFat'],color='blue',hist=False,label='Bodyfat')
# C:\Users\ASUS\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ____________________________________________________________________________________________________
# Distribuation plots for Chest feature is shown
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_24668\555354685.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df[col],color = 'red', hist=False,label=col)
# C:\Users\ASUS\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ____________________________________________________________________________________________________
# Distribuation plots for Abdomen feature is shown
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_24668\555354685.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df['BodyFat'],color='blue',hist=False,label='Bodyfat')
# C:\Users\ASUS\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_24668\555354685.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df[col],color = 'red', hist=False,label=col)
# C:\Users\ASUS\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ____________________________________________________________________________________________________
# Distribuation plots for Hip feature is shown
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_24668\555354685.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df['BodyFat'],color='blue',hist=False,label='Bodyfat')
# C:\Users\ASUS\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_24668\555354685.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df[col],color = 'red', hist=False,label=col)
# C:\Users\ASUS\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_24668\555354685.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df['BodyFat'],color='blue',hist=False,label='Bodyfat')
# C:\Users\ASUS\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ____________________________________________________________________________________________________
# Distribuation plots for Thigh feature is shown
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_24668\555354685.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df[col],color = 'red', hist=False,label=col)
# C:\Users\ASUS\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ____________________________________________________________________________________________________
# Distribuation plots for Knee feature is shown
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_24668\555354685.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df['BodyFat'],color='blue',hist=False,label='Bodyfat')
# C:\Users\ASUS\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_24668\555354685.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df[col],color = 'red', hist=False,label=col)
# C:\Users\ASUS\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ____________________________________________________________________________________________________
# Distribuation plots for Ankle feature is shown
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_24668\555354685.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df['BodyFat'],color='blue',hist=False,label='Bodyfat')
# C:\Users\ASUS\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_24668\555354685.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df[col],color = 'red', hist=False,label=col)
# C:\Users\ASUS\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ____________________________________________________________________________________________________
# Distribuation plots for Biceps feature is shown
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_24668\555354685.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df['BodyFat'],color='blue',hist=False,label='Bodyfat')
# C:\Users\ASUS\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_24668\555354685.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df[col],color = 'red', hist=False,label=col)
# C:\Users\ASUS\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ____________________________________________________________________________________________________
# Distribuation plots for Forearm feature is shown
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_24668\555354685.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df['BodyFat'],color='blue',hist=False,label='Bodyfat')
# C:\Users\ASUS\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_24668\555354685.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df[col],color = 'red', hist=False,label=col)
# C:\Users\ASUS\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ____________________________________________________________________________________________________
# Distribuation plots for Wrist feature is shown
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_24668\555354685.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df['BodyFat'],color='blue',hist=False,label='Bodyfat')
# C:\Users\ASUS\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_24668\555354685.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df[col],color = 'red', hist=False,label=col)
# C:\Users\ASUS\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ____________________________________________________________________________________________________

# %%
import scipy.stats as stats

# %%
def drawplots(df,col):

    plt.figure(figsize=(15,7))
    plt.subplot(1,3,1)
    plt.hist(df[col],color='magenta')

    plt.subplot(1,3,2)
    stats.probplot(df[col],dist='norm', plot=plt)

    plt.subplot(1,3,3)
    sn.boxplot(df[col],color='magenta')

    plt.show()

cols = list(df.columns)
for i in range(len(cols)):

    print(f'Distrubation plots for the feature {cols[i]} are shown')

    drawplots(df,cols[i])

    print("="*100)
# Out:
# Distrubation plots for the feature Density are shown
# ====================================================================================================
# Distrubation plots for the feature BodyFat are shown
# ====================================================================================================
# Distrubation plots for the feature Age are shown
# ====================================================================================================
# Distrubation plots for the feature Weight are shown
# ====================================================================================================
# Distrubation plots for the feature Height are shown
# ====================================================================================================
# Distrubation plots for the feature Neck are shown
# ====================================================================================================
# Distrubation plots for the feature Chest are shown
# ====================================================================================================
# Distrubation plots for the feature Abdomen are shown
# ====================================================================================================
# Distrubation plots for the feature Hip are shown
# ====================================================================================================
# Distrubation plots for the feature Thigh are shown
# ====================================================================================================
# Distrubation plots for the feature Knee are shown
# ====================================================================================================
# Distrubation plots for the feature Ankle are shown
# ====================================================================================================
# Distrubation plots for the feature Biceps are shown
# ====================================================================================================
# Distrubation plots for the feature Forearm are shown
# ====================================================================================================
# Distrubation plots for the feature Wrist are shown
# ====================================================================================================

# %% [markdown]
# ## Checking For Outliers

# %%
upperlimit = []
lowerlimit = []
for i in df.columns:
    upperlimit.append(df[i].mean()+(df[i].std())*4)
    lowerlimit.append(df[i].mean()+(df[i].std())*4)

# %%
## It will help us to find out the outliers.

# %%
cols = list(df.columns)
j=0
for i in range(len(cols)):
    
    temp =df.loc[(df[cols[i]]>upperlimit[j])&(df[cols[i]]<lowerlimit[j])]
    j+=1

# %%
temp
# Out:
# Empty DataFrame
# Columns: [Density, BodyFat, Age, Weight, Height, Neck, Chest, Abdomen, Hip, Thigh, Knee, Ankle, Biceps, Forearm, Wrist]
# Index: []

# %% [markdown]
# # Using Extra Trees Regrerssor for Feature Selection

# %%
data = df.copy()
test = data['BodyFat']
train = data.drop(['BodyFat'],axis=1)

# %%
from sklearn.ensemble import ExtraTreesRegressor
er = ExtraTreesRegressor()
er.fit(train,test)
# Out:
# ExtraTreesRegressor()

# %%
er.feature_importances_
# Out:
# array([0.71818547, 0.00235484, 0.0091584 , 0.00482755, 0.00110717,
#        0.05853005, 0.16195856, 0.01805141, 0.0105716 , 0.00501882,
#        0.00105207, 0.00489055, 0.00221306, 0.00208045])

# %%
series = pd.Series(er.feature_importances_,index=train.columns)
series.nlargest(5).plot(kind = 'barh',color = 'green')
# Out:
# <Axes: >

# %% [markdown]
# # Using Mutual Information Gain For Feature Selection

# %%
from sklearn.feature_selection import mutual_info_regression
mr = mutual_info_regression(train, test)

# %%
plotdata = pd.Series(mr,index=train.columns)
plotdata.nlargest(5).plot(kind = 'barh', color = 'green')
# Out:
# <Axes: >

# %% [markdown]
# ## Removing Correlation

# %%
data
# Out:
#      Density  BodyFat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  \
# 0     1.0708     12.3   23  154.25   67.75  36.2   93.1     85.2   94.5
# 1     1.0853      6.1   22  173.25   72.25  38.5   93.6     83.0   98.7
# 2     1.0414     25.3   22  154.00   66.25  34.0   95.8     87.9   99.2
# 3     1.0751     10.4   26  184.75   72.25  37.4  101.8     86.4  101.2
# 4     1.0340     28.7   24  184.25   71.25  34.4   97.3    100.0  101.9
# ..       ...      ...  ...     ...     ...   ...    ...      ...    ...
# 247   1.0736     11.0   70  134.25   67.00  34.9   89.2     83.6   88.8
# 248   1.0236     33.6   72  201.00   69.75  40.9  108.5    105.0  104.5
# 249   1.0328     29.3   72  186.75   66.00  38.9  111.1    111.5  101.7
# 250   1.0399     26.0   72  190.75   70.50  38.9  108.3    101.3   97.8
# 251   1.0271     31.9   74  207.50   70.00  40.8  112.4    108.5  107.1
#
#      Thigh  Knee  Ankle  Biceps  Forearm  Wrist
# 0     59.0  37.3   21.9    32.0     27.4   17.1
# 1     58.7  37.3   23.4    30.5     28.9   18.2
# 2     59.6  38.9   24.0    28.8     25.2   16.6
# 3     60.1  37.3   22.8    32.4     29.4   18.2
# 4     63.2  42.2   24.0    32.2     27.7   17.7
# ..     ...   ...    ...     ...      ...    ...
# 247   49.6  34.8   21.5    25.6     25.7   18.5
# 248   59.6  40.8   23.2    35.2     28.6   20.1
# 249   60.3  37.3   21.5    31.3     27.2   18.0
# 250   56.0  41.6   22.7    30.5     29.4   19.8
# 251   59.3  42.2   24.6    33.7     30.0   20.9
#
# [252 rows x 15 columns]

# %%
plt.figure(figsize=(15,7))
sn.heatmap(df.corr(), annot=True, cmap='plasma')
# Out:
# <Axes: >

# %%
df.corr()
# Out:
#           Density   BodyFat       Age    Weight    Height      Neck     Chest  \
# Density  1.000000 -0.987782 -0.277637 -0.594062  0.097881 -0.472966 -0.682599
# BodyFat -0.987782  1.000000  0.291458  0.612414 -0.089495  0.490592  0.702620
# Age     -0.277637  0.291458  1.000000 -0.012746 -0.171645  0.113505  0.176450
# Weight  -0.594062  0.612414 -0.012746  1.000000  0.308279  0.830716  0.894191
# Height   0.097881 -0.089495 -0.171645  0.308279  1.000000  0.253710  0.134892
# Neck    -0.472966  0.490592  0.113505  0.830716  0.253710  1.000000  0.784835
# Chest   -0.682599  0.702620  0.176450  0.894191  0.134892  0.784835  1.000000
# Abdomen -0.798955  0.813432  0.230409  0.887995  0.087813  0.754077  0.915828
# Hip     -0.609331  0.625201 -0.050332  0.940884  0.170394  0.734958  0.829420
# Thigh   -0.553091  0.559608 -0.200096  0.868694  0.148436  0.695697  0.729859
# Knee    -0.495040  0.508665  0.017516  0.853167  0.286053  0.672405  0.719496
# Ankle   -0.264890  0.265970 -0.105058  0.613685  0.264744  0.477892  0.482988
# Biceps  -0.487109  0.493271 -0.041162  0.800416  0.207816  0.731146  0.727907
# Forearm -0.351648  0.361387 -0.085056  0.630301  0.228649  0.623660  0.580173
# Wrist   -0.325716  0.346575  0.213531  0.729775  0.322065  0.744826  0.660162
#
#           Abdomen       Hip     Thigh      Knee     Ankle    Biceps   Forearm  \
# Density -0.798955 -0.609331 -0.553091 -0.495040 -0.264890 -0.487109 -0.351648
# BodyFat  0.813432  0.625201  0.559608  0.508665  0.265970  0.493271  0.361387
# Age      0.230409 -0.050332 -0.200096  0.017516 -0.105058 -0.041162 -0.085056
# Weight   0.887995  0.940884  0.868694  0.853167  0.613685  0.800416  0.630301
# Height   0.087813  0.170394  0.148436  0.286053  0.264744  0.207816  0.228649
# Neck     0.754077  0.734958  0.695697  0.672405  0.477892  0.731146  0.623660
# Chest    0.915828  0.829420  0.729859  0.719496  0.482988  0.727907  0.580173
# Abdomen  1.000000  0.874066  0.766624  0.737179  0.453223  0.684983  0.503316
# Hip      0.874066  1.000000  0.896410  0.823473  0.558387  0.739273  0.545014
# Thigh    0.766624  0.896410  1.000000  0.799170  0.539797  0.761477  0.566842
# Knee     0.737179  0.823473  0.799170  1.000000  0.611608  0.678709  0.555898
# Ankle    0.453223  0.558387  0.539797  0.611608  1.000000  0.484855  0.419050
# Biceps   0.684983  0.739273  0.761477  0.678709  0.484855  1.000000  0.678255
# Forearm  0.503316  0.545014  0.566842  0.555898  0.419050  0.678255  1.000000
# Wrist    0.619832  0.630090  0.558685  0.664507  0.566195  0.632126  0.585588
#
#             Wrist
# Density -0.325716
# BodyFat  0.346575
# Age      0.213531
# Weight   0.729775
# Height   0.322065
# Neck     0.744826
# Chest    0.660162
# Abdomen  0.619832
# Hip      0.630090
# Thigh    0.558685
# Knee     0.664507
# Ankle    0.566195
# Biceps   0.632126
# Forearm  0.585588
# Wrist    1.000000

# %%
def correlation (df,threshold):

    colcor = set()

    cormat = df.corr()

    for i in range(len(cormat)):
        for j in range(i): 
            '''
            for each sell get the value of that cell by . iloc[i][j],
            where i is the row and j is the col if that abs (value) is grater
            then the threshold,get the col_name and add it in the set
            '''

            if abs(cormat.iloc[i][j])>threshold:
                colname = cormat.columns[i]
                colcor.add(colname)

    return colcor
            
ans = correlation(train,threshold=0.85)

ans
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_24668\3880417774.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if abs(cormat.iloc[i][j])>threshold:
# {'Abdomen', 'Chest', 'Hip', 'Knee', 'Thigh'}

# %% [markdown]
# ### From the above feature selection techniques we can say that the  features recommended by the `Extra Treees Regressor` and the `mutual_information_gain` are correct and the correlation map we get to observe the similer pattern we noticed that `abdomen` and `hip` are having similer features,they're having colinearlity. same goes with knee and thigh, we can either keep any one of them and we noticed that the feature `abdomen` gave more feature importance score in comparishm to `hips` so i will be selecting that

# %%
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
temp = data[list(data.columns)] 
temp
# Out:
#      Density  BodyFat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  \
# 0     1.0708     12.3   23  154.25   67.75  36.2   93.1     85.2   94.5
# 1     1.0853      6.1   22  173.25   72.25  38.5   93.6     83.0   98.7
# 2     1.0414     25.3   22  154.00   66.25  34.0   95.8     87.9   99.2
# 3     1.0751     10.4   26  184.75   72.25  37.4  101.8     86.4  101.2
# 4     1.0340     28.7   24  184.25   71.25  34.4   97.3    100.0  101.9
# ..       ...      ...  ...     ...     ...   ...    ...      ...    ...
# 247   1.0736     11.0   70  134.25   67.00  34.9   89.2     83.6   88.8
# 248   1.0236     33.6   72  201.00   69.75  40.9  108.5    105.0  104.5
# 249   1.0328     29.3   72  186.75   66.00  38.9  111.1    111.5  101.7
# 250   1.0399     26.0   72  190.75   70.50  38.9  108.3    101.3   97.8
# 251   1.0271     31.9   74  207.50   70.00  40.8  112.4    108.5  107.1
#
#      Thigh  Knee  Ankle  Biceps  Forearm  Wrist
# 0     59.0  37.3   21.9    32.0     27.4   17.1
# 1     58.7  37.3   23.4    30.5     28.9   18.2
# 2     59.6  38.9   24.0    28.8     25.2   16.6
# 3     60.1  37.3   22.8    32.4     29.4   18.2
# 4     63.2  42.2   24.0    32.2     27.7   17.7
# ..     ...   ...    ...     ...      ...    ...
# 247   49.6  34.8   21.5    25.6     25.7   18.5
# 248   59.6  40.8   23.2    35.2     28.6   20.1
# 249   60.3  37.3   21.5    31.3     27.2   18.0
# 250   56.0  41.6   22.7    30.5     29.4   19.8
# 251   59.3  42.2   24.6    33.7     30.0   20.9
#
# [252 rows x 15 columns]

# %%
# temp = data[list(data.columns)]
temp.shape
# Out:
# (252, 15)

# %%
temp.values
# Out:
# array([[ 1.0708, 12.3   , 23.    , ..., 32.    , 27.4   , 17.1   ],
#        [ 1.0853,  6.1   , 22.    , ..., 30.5   , 28.9   , 18.2   ],
#        [ 1.0414, 25.3   , 22.    , ..., 28.8   , 25.2   , 16.6   ],
#        ...,
#        [ 1.0328, 29.3   , 72.    , ..., 31.3   , 27.2   , 18.    ],
#        [ 1.0399, 26.    , 72.    , ..., 30.5   , 29.4   , 19.8   ],
#        [ 1.0271, 31.9   , 74.    , ..., 33.7   , 30.    , 20.9   ]])

# %%
temp = data[list(data.columns)] 
info = pd.DataFrame()
info['VIF'] = [variance_inflation_factor(temp.values,i) for i in range (temp.shape[1])]
info['column'] = temp.columns
info
# Out:
#             VIF   column
# 0   3695.622377  Density
# 1     33.845429  BodyFat
# 2     31.376101      Age
# 3   1238.097164   Weight
# 4    613.410514   Height
# 5   1081.965633     Neck
# 6   1374.457425    Chest
# 7   1332.624257  Abdomen
# 8   2933.636131      Hip
# 9   1017.257501    Thigh
# 10  1187.890413     Knee
# 11   356.293529    Ankle
# 12   419.391664   Biceps
# 13   454.571766  Forearm
# 14  1349.973920    Wrist

# %%
cols1 = list(series.nlargest(5).index)
cols2 = list(plotdata.nlargest(5).index)

cols1,cols2
# Out:
# (['Density', 'Abdomen', 'Chest', 'Hip', 'Thigh'],
#  ['Density', 'Abdomen', 'Chest', 'Hip', 'Thigh'])

# %% [markdown]
# ##### we'll go with the `weight and hip` method, as `Hip` and `Thigh` are very much related, so we'll select the cols1 and drop every other feature, if that doesn't produce any furter importance we will try with some other feature.

# %%
totrain = train[cols1]
totrain.head()
# Out:
#    Density  Abdomen  Chest    Hip  Thigh
# 0   1.0708     85.2   93.1   94.5   59.0
# 1   1.0853     83.0   93.6   98.7   58.7
# 2   1.0414     87.9   95.8   99.2   59.6
# 3   1.0751     86.4  101.8  101.2   60.1
# 4   1.0340    100.0   97.3  101.9   63.2

# %%
from sklearn.model_selection import train_test_split,RandomizedSearchCV
from sklearn import metrics
from sklearn import tree
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.linear_model import LinearRegression,Lasso,Ridge

# %%
X_train, X_test , y_train, y_test = train_test_split(totrain,test,test_size=0.2)
X_train.shape,X_test.shape
# Out:
# ((201, 5), (51, 5))

# %%
reg = DecisionTreeRegressor()
reg.fit(X_train,y_train)
plt.figure(figure=(15,7))
tree.plot_tree(reg,filled=True)
# Out:
# [Text(0.49049202127659575, 0.9545454545454546, 'x[0] <= 1.056\nsquared_error = 71.932\nsamples = 201\nvalue = 19.277'),
#  Text(0.19441489361702127, 0.8636363636363636, 'x[0] <= 1.036\nsquared_error = 26.305\nsamples = 108\nvalue = 25.754'),
#  Text(0.04468085106382979, 0.7727272727272727, 'x[0] <= 1.017\nsquared_error = 15.069\nsamples = 34\nvalue = 31.929'),
#  Text(0.00851063829787234, 0.6818181818181818, 'x[0] <= 1.003\nsquared_error = 16.347\nsamples = 3\nvalue = 41.9'),
#  Text(0.00425531914893617, 0.5909090909090909, 'squared_error = 0.0\nsamples = 1\nvalue = 47.5'),
#  Text(0.01276595744680851, 0.5909090909090909, 'x[4] <= 65.2\nsquared_error = 1.0\nsamples = 2\nvalue = 39.1'),
#  Text(0.00851063829787234, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 40.1'),
#  Text(0.01702127659574468, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 38.1'),
#  Text(0.08085106382978724, 0.6818181818181818, 'x[0] <= 1.029\nsquared_error = 4.394\nsamples = 31\nvalue = 30.965'),
#  Text(0.04148936170212766, 0.5909090909090909, 'x[0] <= 1.024\nsquared_error = 1.49\nsamples = 15\nvalue = 32.84'),
#  Text(0.02553191489361702, 0.5, 'x[4] <= 60.45\nsquared_error = 0.388\nsamples = 4\nvalue = 34.65'),
#  Text(0.02127659574468085, 0.4090909090909091, 'squared_error = 0.0\nsamples = 1\nvalue = 33.6'),
#  Text(0.029787234042553193, 0.4090909090909091, 'x[4] <= 75.4\nsquared_error = 0.027\nsamples = 3\nvalue = 35.0'),
#  Text(0.02553191489361702, 0.3181818181818182, 'x[0] <= 1.021\nsquared_error = 0.01\nsamples = 2\nvalue = 34.9'),
#  Text(0.02127659574468085, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 35.0'),
#  Text(0.029787234042553193, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 34.8'),
#  Text(0.03404255319148936, 0.3181818181818182, 'squared_error = -0.0\nsamples = 1\nvalue = 35.2'),
#  Text(0.0574468085106383, 0.5, 'x[0] <= 1.027\nsquared_error = 0.267\nsamples = 11\nvalue = 32.182'),
#  Text(0.04680851063829787, 0.4090909090909091, 'x[0] <= 1.026\nsquared_error = 0.06\nsamples = 6\nvalue = 32.6'),
#  Text(0.0425531914893617, 0.3181818181818182, 'x[0] <= 1.025\nsquared_error = 0.023\nsamples = 4\nvalue = 32.75'),
#  Text(0.03829787234042553, 0.22727272727272727, 'squared_error = 0.0\nsamples = 2\nvalue = 32.9'),
#  Text(0.04680851063829787, 0.22727272727272727, 'x[2] <= 115.3\nsquared_error = 0.0\nsamples = 2\nvalue = 32.6'),
#  Text(0.0425531914893617, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 32.6'),
#  Text(0.05106382978723404, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 32.6'),
#  Text(0.05106382978723404, 0.3181818181818182, 'squared_error = -0.0\nsamples = 2\nvalue = 32.3'),
#  Text(0.06808510638297872, 0.4090909090909091, 'x[0] <= 1.027\nsquared_error = 0.054\nsamples = 5\nvalue = 31.68'),
#  Text(0.059574468085106386, 0.3181818181818182, 'x[2] <= 109.5\nsquared_error = 0.002\nsamples = 2\nvalue = 31.95'),
#  Text(0.05531914893617021, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 32.0'),
#  Text(0.06382978723404255, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 31.9'),
#  Text(0.07659574468085106, 0.3181818181818182, 'x[1] <= 100.55\nsquared_error = 0.007\nsamples = 3\nvalue = 31.5'),
#  Text(0.07234042553191489, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 31.4'),
#  Text(0.08085106382978724, 0.22727272727272727, 'x[4] <= 63.4\nsquared_error = 0.002\nsamples = 2\nvalue = 31.55'),
#  Text(0.07659574468085106, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 31.5'),
#  Text(0.0851063829787234, 0.13636363636363635, 'squared_error = -0.0\nsamples = 1\nvalue = 31.6'),
#  Text(0.1202127659574468, 0.5909090909090909, 'x[0] <= 1.033\nsquared_error = 0.727\nsamples = 16\nvalue = 29.206'),
#  Text(0.1, 0.5, 'x[0] <= 1.031\nsquared_error = 0.168\nsamples = 8\nvalue = 29.95'),
#  Text(0.08936170212765958, 0.4090909090909091, 'x[3] <= 104.25\nsquared_error = 0.023\nsamples = 2\nvalue = 30.55'),
#  Text(0.0851063829787234, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 30.7'),
#  Text(0.09361702127659574, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 30.4'),
#  Text(0.11063829787234042, 0.4090909090909091, 'x[0] <= 1.032\nsquared_error = 0.056\nsamples = 6\nvalue = 29.75'),
#  Text(0.10212765957446808, 0.3181818181818182, 'x[2] <= 102.95\nsquared_error = 0.005\nsamples = 4\nvalue = 29.9'),
#  Text(0.09787234042553192, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 29.8'),
#  Text(0.10638297872340426, 0.22727272727272727, 'x[2] <= 104.7\nsquared_error = 0.002\nsamples = 3\nvalue = 29.933'),
#  Text(0.10212765957446808, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 30.0'),
#  Text(0.11063829787234042, 0.13636363636363635, 'squared_error = -0.0\nsamples = 2\nvalue = 29.9'),
#  Text(0.11914893617021277, 0.3181818181818182, 'x[0] <= 1.032\nsquared_error = 0.023\nsamples = 2\nvalue = 29.45'),
#  Text(0.1148936170212766, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 29.6'),
#  Text(0.12340425531914893, 0.22727272727272727, 'squared_error = -0.0\nsamples = 1\nvalue = 29.3'),
#  Text(0.14042553191489363, 0.5, 'x[0] <= 1.034\nsquared_error = 0.18\nsamples = 8\nvalue = 28.462'),
#  Text(0.13191489361702127, 0.4090909090909091, 'x[0] <= 1.034\nsquared_error = 0.022\nsamples = 4\nvalue = 28.85'),
#  Text(0.1276595744680851, 0.3181818181818182, 'squared_error = 0.0\nsamples = 2\nvalue = 29.0'),
#  Text(0.13617021276595745, 0.3181818181818182, 'squared_error = -0.0\nsamples = 2\nvalue = 28.7'),
#  Text(0.14893617021276595, 0.4090909090909091, 'x[4] <= 64.85\nsquared_error = 0.037\nsamples = 4\nvalue = 28.075'),
#  Text(0.14468085106382977, 0.3181818181818182, 'x[0] <= 1.036\nsquared_error = 0.002\nsamples = 3\nvalue = 27.967'),
#  Text(0.14042553191489363, 0.22727272727272727, 'squared_error = -0.0\nsamples = 2\nvalue = 28.0'),
#  Text(0.14893617021276595, 0.22727272727272727, 'squared_error = -0.0\nsamples = 1\nvalue = 27.9'),
#  Text(0.15319148936170213, 0.3181818181818182, 'squared_error = -0.0\nsamples = 1\nvalue = 28.4'),
#  Text(0.34414893617021275, 0.7727272727272727, 'x[0] <= 1.047\nsquared_error = 5.892\nsamples = 74\nvalue = 22.916'),
#  Text(0.2478723404255319, 0.6818181818181818, 'x[0] <= 1.042\nsquared_error = 1.297\nsamples = 33\nvalue = 25.297'),
#  Text(0.19680851063829788, 0.5909090909090909, 'x[0] <= 1.039\nsquared_error = 0.476\nsamples = 20\nvalue = 26.05'),
#  Text(0.17446808510638298, 0.5, 'x[0] <= 1.038\nsquared_error = 0.084\nsamples = 7\nvalue = 26.886'),
#  Text(0.16595744680851063, 0.4090909090909091, 'x[0] <= 1.037\nsquared_error = 0.02\nsamples = 3\nvalue = 27.2'),
#  Text(0.16170212765957448, 0.3181818181818182, 'x[4] <= 63.6\nsquared_error = 0.0\nsamples = 2\nvalue = 27.3'),
#  Text(0.1574468085106383, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 27.3'),
#  Text(0.16595744680851063, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 27.3'),
#  Text(0.1702127659574468, 0.3181818181818182, 'squared_error = -0.0\nsamples = 1\nvalue = 27.0'),
#  Text(0.1829787234042553, 0.4090909090909091, 'x[0] <= 1.039\nsquared_error = 0.003\nsamples = 4\nvalue = 26.65'),
#  Text(0.17872340425531916, 0.3181818181818182, 'squared_error = 0.0\nsamples = 2\nvalue = 26.7'),
#  Text(0.18723404255319148, 0.3181818181818182, 'x[3] <= 103.0\nsquared_error = 0.0\nsamples = 2\nvalue = 26.6'),
#  Text(0.1829787234042553, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 26.6'),
#  Text(0.19148936170212766, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 26.6'),
#  Text(0.21914893617021278, 0.5, 'x[0] <= 1.041\nsquared_error = 0.109\nsamples = 13\nvalue = 25.6'),
#  Text(0.20851063829787234, 0.4090909090909091, 'x[0] <= 1.04\nsquared_error = 0.019\nsamples = 6\nvalue = 25.933'),
#  Text(0.20425531914893616, 0.3181818181818182, 'x[4] <= 62.9\nsquared_error = 0.002\nsamples = 3\nvalue = 26.067'),
#  Text(0.2, 0.22727272727272727, 'squared_error = 0.0\nsamples = 2\nvalue = 26.1'),
#  Text(0.20851063829787234, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 26.0'),
#  Text(0.2127659574468085, 0.3181818181818182, 'squared_error = 0.0\nsamples = 3\nvalue = 25.8'),
#  Text(0.2297872340425532, 0.4090909090909091, 'x[0] <= 1.041\nsquared_error = 0.01\nsamples = 7\nvalue = 25.314'),
#  Text(0.22127659574468084, 0.3181818181818182, 'x[3] <= 100.05\nsquared_error = 0.002\nsamples = 2\nvalue = 25.45'),
#  Text(0.2170212765957447, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 25.4'),
#  Text(0.225531914893617, 0.22727272727272727, 'squared_error = -0.0\nsamples = 1\nvalue = 25.5'),
#  Text(0.23829787234042554, 0.3181818181818182, 'x[0] <= 1.041\nsquared_error = 0.002\nsamples = 5\nvalue = 25.26'),
#  Text(0.23404255319148937, 0.22727272727272727, 'x[1] <= 93.0\nsquared_error = 0.0\nsamples = 3\nvalue = 25.3'),
#  Text(0.2297872340425532, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 25.3'),
#  Text(0.23829787234042554, 0.13636363636363635, 'squared_error = -0.0\nsamples = 2\nvalue = 25.3'),
#  Text(0.2425531914893617, 0.22727272727272727, 'squared_error = 0.0\nsamples = 2\nvalue = 25.2'),
#  Text(0.298936170212766, 0.5909090909090909, 'x[0] <= 1.045\nsquared_error = 0.345\nsamples = 13\nvalue = 24.138'),
#  Text(0.27872340425531916, 0.5, 'x[0] <= 1.043\nsquared_error = 0.039\nsamples = 8\nvalue = 24.575'),
#  Text(0.26382978723404255, 0.4090909090909091, 'x[1] <= 98.25\nsquared_error = 0.013\nsamples = 4\nvalue = 24.75'),
#  Text(0.2553191489361702, 0.3181818181818182, 'x[1] <= 95.65\nsquared_error = 0.002\nsamples = 2\nvalue = 24.85'),
#  Text(0.251063829787234, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 24.9'),
#  Text(0.25957446808510637, 0.22727272727272727, 'squared_error = -0.0\nsamples = 1\nvalue = 24.8'),
#  Text(0.2723404255319149, 0.3181818181818182, 'x[2] <= 105.75\nsquared_error = 0.003\nsamples = 2\nvalue = 24.65'),
#  Text(0.2680851063829787, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 24.6'),
#  Text(0.2765957446808511, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 24.7'),
#  Text(0.2936170212765957, 0.4090909090909091, 'x[4] <= 62.7\nsquared_error = 0.005\nsamples = 4\nvalue = 24.4'),
#  Text(0.28936170212765955, 0.3181818181818182, 'x[2] <= 98.0\nsquared_error = 0.002\nsamples = 3\nvalue = 24.367'),
#  Text(0.2851063829787234, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 24.3'),
#  Text(0.2936170212765957, 0.22727272727272727, 'squared_error = 0.0\nsamples = 2\nvalue = 24.4'),
#  Text(0.2978723404255319, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 24.5'),
#  Text(0.3191489361702128, 0.5, 'x[4] <= 58.15\nsquared_error = 0.042\nsamples = 5\nvalue = 23.44'),
#  Text(0.31063829787234043, 0.4090909090909091, 'x[4] <= 57.45\nsquared_error = 0.01\nsamples = 2\nvalue = 23.2'),
#  Text(0.30638297872340425, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 23.3'),
#  Text(0.3148936170212766, 0.3181818181818182, 'squared_error = -0.0\nsamples = 1\nvalue = 23.1'),
#  Text(0.3276595744680851, 0.4090909090909091, 'x[0] <= 1.045\nsquared_error = 0.0\nsamples = 3\nvalue = 23.6'),
#  Text(0.32340425531914896, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 23.6'),
#  Text(0.33191489361702126, 0.3181818181818182, 'squared_error = -0.0\nsamples = 2\nvalue = 23.6'),
#  Text(0.44042553191489364, 0.6818181818181818, 'x[0] <= 1.051\nsquared_error = 1.357\nsamples = 41\nvalue = 21.0'),
#  Text(0.3893617021276596, 0.5909090909090909, 'x[0] <= 1.049\nsquared_error = 0.339\nsamples = 20\nvalue = 22.02'),
#  Text(0.3659574468085106, 0.5, 'x[0] <= 1.048\nsquared_error = 0.099\nsamples = 12\nvalue = 22.425'),
#  Text(0.34893617021276596, 0.4090909090909091, 'x[0] <= 1.047\nsquared_error = 0.022\nsamples = 5\nvalue = 22.76'),
#  Text(0.3404255319148936, 0.3181818181818182, 'x[2] <= 94.8\nsquared_error = 0.002\nsamples = 3\nvalue = 22.867'),
#  Text(0.33617021276595743, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 22.8'),
#  Text(0.3446808510638298, 0.22727272727272727, 'squared_error = -0.0\nsamples = 2\nvalue = 22.9'),
#  Text(0.3574468085106383, 0.3181818181818182, 'x[0] <= 1.047\nsquared_error = 0.01\nsamples = 2\nvalue = 22.6'),
#  Text(0.35319148936170214, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 22.7'),
#  Text(0.3617021276595745, 0.22727272727272727, 'squared_error = -0.0\nsamples = 1\nvalue = 22.5'),
#  Text(0.3829787234042553, 0.4090909090909091, 'x[0] <= 1.048\nsquared_error = 0.016\nsamples = 7\nvalue = 22.186'),
#  Text(0.37446808510638296, 0.3181818181818182, 'x[1] <= 92.0\nsquared_error = 0.002\nsamples = 2\nvalue = 22.35'),
#  Text(0.3702127659574468, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 22.4'),
#  Text(0.37872340425531914, 0.22727272727272727, 'squared_error = -0.0\nsamples = 1\nvalue = 22.3'),
#  Text(0.39148936170212767, 0.3181818181818182, 'x[2] <= 101.65\nsquared_error = 0.006\nsamples = 5\nvalue = 22.12'),
#  Text(0.3872340425531915, 0.22727272727272727, 'x[1] <= 90.5\nsquared_error = 0.002\nsamples = 3\nvalue = 22.067'),
#  Text(0.3829787234042553, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 22.0'),
#  Text(0.39148936170212767, 0.13636363636363635, 'squared_error = 0.0\nsamples = 2\nvalue = 22.1'),
#  Text(0.39574468085106385, 0.22727272727272727, 'squared_error = -0.0\nsamples = 2\nvalue = 22.2'),
#  Text(0.4127659574468085, 0.5, 'x[3] <= 101.15\nsquared_error = 0.084\nsamples = 8\nvalue = 21.412'),
#  Text(0.40425531914893614, 0.4090909090909091, 'x[0] <= 1.05\nsquared_error = 0.028\nsamples = 5\nvalue = 21.6'),
#  Text(0.4, 0.3181818181818182, 'squared_error = 0.0\nsamples = 2\nvalue = 21.8'),
#  Text(0.4085106382978723, 0.3181818181818182, 'x[0] <= 1.05\nsquared_error = 0.002\nsamples = 3\nvalue = 21.467'),
#  Text(0.40425531914893614, 0.22727272727272727, 'squared_error = -0.0\nsamples = 2\nvalue = 21.5'),
#  Text(0.4127659574468085, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 21.4'),
#  Text(0.42127659574468085, 0.4090909090909091, 'x[1] <= 94.7\nsquared_error = 0.02\nsamples = 3\nvalue = 21.1'),
#  Text(0.41702127659574467, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 20.9'),
#  Text(0.425531914893617, 0.3181818181818182, 'x[1] <= 98.4\nsquared_error = 0.0\nsamples = 2\nvalue = 21.2'),
#  Text(0.42127659574468085, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 21.2'),
#  Text(0.4297872340425532, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 21.2'),
#  Text(0.49148936170212765, 0.5909090909090909, 'x[0] <= 1.053\nsquared_error = 0.392\nsamples = 21\nvalue = 20.029'),
#  Text(0.46808510638297873, 0.5, 'x[0] <= 1.052\nsquared_error = 0.08\nsamples = 12\nvalue = 20.525'),
#  Text(0.451063829787234, 0.4090909090909091, 'x[2] <= 101.55\nsquared_error = 0.007\nsamples = 4\nvalue = 20.875'),
#  Text(0.4425531914893617, 0.3181818181818182, 'x[3] <= 102.1\nsquared_error = 0.002\nsamples = 2\nvalue = 20.95'),
#  Text(0.43829787234042555, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 20.9'),
#  Text(0.44680851063829785, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 21.0'),
#  Text(0.4595744680851064, 0.3181818181818182, 'x[4] <= 62.55\nsquared_error = 0.0\nsamples = 2\nvalue = 20.8'),
#  Text(0.4553191489361702, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 20.8'),
#  Text(0.46382978723404256, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 20.8'),
#  Text(0.4851063829787234, 0.4090909090909091, 'x[0] <= 1.053\nsquared_error = 0.025\nsamples = 8\nvalue = 20.35'),
#  Text(0.4765957446808511, 0.3181818181818182, 'x[0] <= 1.052\nsquared_error = 0.006\nsamples = 6\nvalue = 20.433'),
#  Text(0.4723404255319149, 0.22727272727272727, 'squared_error = 0.0\nsamples = 3\nvalue = 20.5'),
#  Text(0.4808510638297872, 0.22727272727272727, 'x[0] <= 1.052\nsquared_error = 0.002\nsamples = 3\nvalue = 20.367'),
#  Text(0.4765957446808511, 0.13636363636363635, 'squared_error = 0.0\nsamples = 2\nvalue = 20.4'),
#  Text(0.4851063829787234, 0.13636363636363635, 'squared_error = -0.0\nsamples = 1\nvalue = 20.3'),
#  Text(0.49361702127659574, 0.3181818181818182, 'x[0] <= 1.053\nsquared_error = 0.0\nsamples = 2\nvalue = 20.1'),
#  Text(0.48936170212765956, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 20.1'),
#  Text(0.4978723404255319, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 20.1'),
#  Text(0.5148936170212766, 0.5, 'x[0] <= 1.054\nsquared_error = 0.04\nsamples = 9\nvalue = 19.367'),
#  Text(0.5063829787234042, 0.4090909090909091, 'x[1] <= 90.15\nsquared_error = 0.007\nsamples = 4\nvalue = 19.575'),
#  Text(0.502127659574468, 0.3181818181818182, 'squared_error = 0.0\nsamples = 2\nvalue = 19.5'),
#  Text(0.5106382978723404, 0.3181818181818182, 'x[3] <= 106.85\nsquared_error = 0.002\nsamples = 2\nvalue = 19.65'),
#  Text(0.5063829787234042, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 19.7'),
#  Text(0.5148936170212766, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 19.6'),
#  Text(0.5234042553191489, 0.4090909090909091, 'x[0] <= 1.055\nsquared_error = 0.004\nsamples = 5\nvalue = 19.2'),
#  Text(0.5191489361702127, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 19.3'),
#  Text(0.5276595744680851, 0.3181818181818182, 'x[0] <= 1.055\nsquared_error = 0.002\nsamples = 4\nvalue = 19.175'),
#  Text(0.5234042553191489, 0.22727272727272727, 'squared_error = 0.0\nsamples = 3\nvalue = 19.2'),
#  Text(0.5319148936170213, 0.22727272727272727, 'squared_error = -0.0\nsamples = 1\nvalue = 19.1'),
#  Text(0.7865691489361702, 0.8636363636363636, 'x[0] <= 1.073\nsquared_error = 19.638\nsamples = 93\nvalue = 11.756'),
#  Text(0.6574468085106383, 0.7727272727272727, 'x[0] <= 1.066\nsquared_error = 6.244\nsamples = 52\nvalue = 14.8'),
#  Text(0.6069148936170212, 0.6818181818181818, 'x[0] <= 1.062\nsquared_error = 1.39\nsamples = 29\nvalue = 16.621'),
#  Text(0.5776595744680851, 0.5909090909090909, 'x[0] <= 1.059\nsquared_error = 0.447\nsamples = 18\nvalue = 17.411'),
#  Text(0.5553191489361702, 0.5, 'x[0] <= 1.058\nsquared_error = 0.136\nsamples = 9\nvalue = 18.0'),
#  Text(0.5404255319148936, 0.4090909090909091, 'x[3] <= 96.5\nsquared_error = 0.028\nsamples = 5\nvalue = 18.3'),
#  Text(0.5361702127659574, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 18.6'),
#  Text(0.5446808510638298, 0.3181818181818182, 'x[0] <= 1.057\nsquared_error = 0.007\nsamples = 4\nvalue = 18.225'),
#  Text(0.5404255319148936, 0.22727272727272727, 'squared_error = 0.0\nsamples = 2\nvalue = 18.3'),
#  Text(0.548936170212766, 0.22727272727272727, 'x[1] <= 90.35\nsquared_error = 0.003\nsamples = 2\nvalue = 18.15'),
#  Text(0.5446808510638298, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 18.1'),
#  Text(0.5531914893617021, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 18.2'),
#  Text(0.5702127659574469, 0.4090909090909091, 'x[1] <= 89.8\nsquared_error = 0.017\nsamples = 4\nvalue = 17.625'),
#  Text(0.5617021276595745, 0.3181818181818182, 'x[1] <= 88.95\nsquared_error = 0.002\nsamples = 2\nvalue = 17.75'),
#  Text(0.5574468085106383, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 17.8'),
#  Text(0.5659574468085107, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 17.7'),
#  Text(0.5787234042553191, 0.3181818181818182, 'x[1] <= 90.15\nsquared_error = 0.0\nsamples = 2\nvalue = 17.5'),
#  Text(0.574468085106383, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 17.5'),
#  Text(0.5829787234042553, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 17.5'),
#  Text(0.6, 0.5, 'x[0] <= 1.061\nsquared_error = 0.064\nsamples = 9\nvalue = 16.822'),
#  Text(0.5914893617021276, 0.4090909090909091, 'x[2] <= 92.55\nsquared_error = 0.022\nsamples = 5\nvalue = 17.02'),
#  Text(0.5872340425531914, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 17.3'),
#  Text(0.5957446808510638, 0.3181818181818182, 'x[0] <= 1.06\nsquared_error = 0.002\nsamples = 4\nvalue = 16.95'),
#  Text(0.5914893617021276, 0.22727272727272727, 'squared_error = 0.0\nsamples = 2\nvalue = 17.0'),
#  Text(0.6, 0.22727272727272727, 'squared_error = -0.0\nsamples = 2\nvalue = 16.9'),
#  Text(0.6085106382978723, 0.4090909090909091, 'x[1] <= 88.7\nsquared_error = 0.007\nsamples = 4\nvalue = 16.575'),
#  Text(0.6042553191489362, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 16.7'),
#  Text(0.6127659574468085, 0.3181818181818182, 'x[1] <= 93.55\nsquared_error = 0.002\nsamples = 3\nvalue = 16.533'),
#  Text(0.6085106382978723, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 16.5'),
#  Text(0.6170212765957447, 0.22727272727272727, 'x[3] <= 105.5\nsquared_error = 0.002\nsamples = 2\nvalue = 16.55'),
#  Text(0.6127659574468085, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 16.6'),
#  Text(0.6212765957446809, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 16.5'),
#  Text(0.6361702127659574, 0.5909090909090909, 'x[0] <= 1.064\nsquared_error = 0.238\nsamples = 11\nvalue = 15.327'),
#  Text(0.6212765957446809, 0.5, 'x[4] <= 57.75\nsquared_error = 0.037\nsamples = 4\nvalue = 15.925'),
#  Text(0.6170212765957447, 0.4090909090909091, 'squared_error = 0.0\nsamples = 1\nvalue = 15.6'),
#  Text(0.625531914893617, 0.4090909090909091, 'x[0] <= 1.062\nsquared_error = 0.002\nsamples = 3\nvalue = 16.033'),
#  Text(0.6212765957446809, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 16.1'),
#  Text(0.6297872340425532, 0.3181818181818182, 'squared_error = 0.0\nsamples = 2\nvalue = 16.0'),
#  Text(0.6510638297872341, 0.5, 'x[0] <= 1.065\nsquared_error = 0.033\nsamples = 7\nvalue = 14.986'),
#  Text(0.6425531914893617, 0.4090909090909091, 'x[0] <= 1.064\nsquared_error = 0.007\nsamples = 4\nvalue = 15.125'),
#  Text(0.6382978723404256, 0.3181818181818182, 'squared_error = 0.0\nsamples = 2\nvalue = 15.2'),
#  Text(0.6468085106382979, 0.3181818181818182, 'x[2] <= 91.55\nsquared_error = 0.002\nsamples = 2\nvalue = 15.05'),
#  Text(0.6425531914893617, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 15.1'),
#  Text(0.6510638297872341, 0.22727272727272727, 'squared_error = -0.0\nsamples = 1\nvalue = 15.0'),
#  Text(0.6595744680851063, 0.4090909090909091, 'x[0] <= 1.065\nsquared_error = 0.007\nsamples = 3\nvalue = 14.8'),
#  Text(0.6553191489361702, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 14.9'),
#  Text(0.6638297872340425, 0.3181818181818182, 'x[0] <= 1.065\nsquared_error = 0.002\nsamples = 2\nvalue = 14.75'),
#  Text(0.6595744680851063, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 14.8'),
#  Text(0.6680851063829787, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 14.7'),
#  Text(0.7079787234042553, 0.6818181818181818, 'x[0] <= 1.067\nsquared_error = 2.914\nsamples = 23\nvalue = 12.504'),
#  Text(0.6872340425531915, 0.5909090909090909, 'x[0] <= 1.066\nsquared_error = 18.49\nsamples = 2\nvalue = 9.9'),
#  Text(0.6829787234042554, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 14.2'),
#  Text(0.6914893617021277, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 5.6'),
#  Text(0.7287234042553191, 0.5909090909090909, 'x[0] <= 1.07\nsquared_error = 0.723\nsamples = 21\nvalue = 12.752'),
#  Text(0.7, 0.5, 'x[0] <= 1.068\nsquared_error = 0.15\nsamples = 10\nvalue = 13.55'),
#  Text(0.6893617021276596, 0.4090909090909091, 'x[0] <= 1.068\nsquared_error = 0.027\nsamples = 7\nvalue = 13.786'),
#  Text(0.6808510638297872, 0.3181818181818182, 'x[3] <= 94.9\nsquared_error = 0.006\nsamples = 5\nvalue = 13.88'),
#  Text(0.676595744680851, 0.22727272727272727, 'squared_error = 0.0\nsamples = 2\nvalue = 13.8'),
#  Text(0.6851063829787234, 0.22727272727272727, 'x[1] <= 78.9\nsquared_error = 0.002\nsamples = 3\nvalue = 13.933'),
#  Text(0.6808510638297872, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 14.0'),
#  Text(0.6893617021276596, 0.13636363636363635, 'x[4] <= 57.6\nsquared_error = 0.0\nsamples = 2\nvalue = 13.9'),
#  Text(0.6851063829787234, 0.045454545454545456, 'squared_error = 0.0\nsamples = 1\nvalue = 13.9'),
#  Text(0.6936170212765957, 0.045454545454545456, 'squared_error = 0.0\nsamples = 1\nvalue = 13.9'),
#  Text(0.6978723404255319, 0.3181818181818182, 'x[3] <= 92.45\nsquared_error = 0.003\nsamples = 2\nvalue = 13.55'),
#  Text(0.6936170212765957, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 13.5'),
#  Text(0.7021276595744681, 0.22727272727272727, 'squared_error = -0.0\nsamples = 1\nvalue = 13.6'),
#  Text(0.7106382978723405, 0.4090909090909091, 'x[2] <= 93.5\nsquared_error = 0.007\nsamples = 3\nvalue = 13.0'),
#  Text(0.7063829787234043, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 13.1'),
#  Text(0.7148936170212766, 0.3181818181818182, 'x[1] <= 88.35\nsquared_error = 0.002\nsamples = 2\nvalue = 12.95'),
#  Text(0.7106382978723405, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 12.9'),
#  Text(0.7191489361702128, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 13.0'),
#  Text(0.7574468085106383, 0.5, 'x[0] <= 1.071\nsquared_error = 0.14\nsamples = 11\nvalue = 12.027'),
#  Text(0.7404255319148936, 0.4090909090909091, 'x[0] <= 1.071\nsquared_error = 0.022\nsamples = 6\nvalue = 12.333'),
#  Text(0.7319148936170212, 0.3181818181818182, 'x[1] <= 83.35\nsquared_error = 0.002\nsamples = 3\nvalue = 12.467'),
#  Text(0.7276595744680852, 0.22727272727272727, 'squared_error = 0.0\nsamples = 2\nvalue = 12.5'),
#  Text(0.7361702127659574, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 12.4'),
#  Text(0.7489361702127659, 0.3181818181818182, 'x[0] <= 1.071\nsquared_error = 0.007\nsamples = 3\nvalue = 12.2'),
#  Text(0.7446808510638298, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 12.3'),
#  Text(0.7531914893617021, 0.22727272727272727, 'x[1] <= 88.0\nsquared_error = 0.002\nsamples = 2\nvalue = 12.15'),
#  Text(0.7489361702127659, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 12.1'),
#  Text(0.7574468085106383, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 12.2'),
#  Text(0.774468085106383, 0.4090909090909091, 'x[0] <= 1.072\nsquared_error = 0.034\nsamples = 5\nvalue = 11.66'),
#  Text(0.7659574468085106, 0.3181818181818182, 'x[0] <= 1.072\nsquared_error = 0.007\nsamples = 3\nvalue = 11.8'),
#  Text(0.7617021276595745, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 11.9'),
#  Text(0.7702127659574468, 0.22727272727272727, 'x[1] <= 83.85\nsquared_error = 0.002\nsamples = 2\nvalue = 11.75'),
#  Text(0.7659574468085106, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 11.8'),
#  Text(0.774468085106383, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 11.7'),
#  Text(0.7829787234042553, 0.3181818181818182, 'x[4] <= 54.2\nsquared_error = 0.003\nsamples = 2\nvalue = 11.45'),
#  Text(0.7787234042553192, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 11.5'),
#  Text(0.7872340425531915, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 11.4'),
#  Text(0.9156914893617021, 0.7727272727272727, 'x[0] <= 1.082\nsquared_error = 9.967\nsamples = 41\nvalue = 7.895'),
#  Text(0.8643617021276596, 0.6818181818181818, 'x[0] <= 1.078\nsquared_error = 1.078\nsamples = 25\nvalue = 9.5'),
#  Text(0.8287234042553191, 0.5909090909090909, 'x[0] <= 1.076\nsquared_error = 0.336\nsamples = 15\nvalue = 10.233'),
#  Text(0.8042553191489362, 0.5, 'x[0] <= 1.074\nsquared_error = 0.105\nsamples = 7\nvalue = 10.757'),
#  Text(0.7957446808510639, 0.4090909090909091, 'x[0] <= 1.073\nsquared_error = 0.035\nsamples = 4\nvalue = 11.0'),
#  Text(0.7914893617021277, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 11.3'),
#  Text(0.8, 0.3181818181818182, 'x[3] <= 88.65\nsquared_error = 0.007\nsamples = 3\nvalue = 10.9'),
#  Text(0.7957446808510639, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 10.8'),
#  Text(0.8042553191489362, 0.22727272727272727, 'x[1] <= 89.45\nsquared_error = 0.002\nsamples = 2\nvalue = 10.95'),
#  Text(0.8, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 11.0'),
#  Text(0.8085106382978723, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 10.9'),
#  Text(0.8127659574468085, 0.4090909090909091, 'x[0] <= 1.075\nsquared_error = 0.016\nsamples = 3\nvalue = 10.433'),
#  Text(0.8085106382978723, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 10.6'),
#  Text(0.8170212765957446, 0.3181818181818182, 'x[0] <= 1.075\nsquared_error = 0.002\nsamples = 2\nvalue = 10.35'),
#  Text(0.8127659574468085, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 10.4'),
#  Text(0.8212765957446808, 0.22727272727272727, 'squared_error = -0.0\nsamples = 1\nvalue = 10.3'),
#  Text(0.8531914893617021, 0.5, 'x[0] <= 1.077\nsquared_error = 0.087\nsamples = 8\nvalue = 9.775'),
#  Text(0.8425531914893617, 0.4090909090909091, 'x[0] <= 1.076\nsquared_error = 0.013\nsamples = 4\nvalue = 10.05'),
#  Text(0.8340425531914893, 0.3181818181818182, 'x[4] <= 53.1\nsquared_error = 0.003\nsamples = 2\nvalue = 10.15'),
#  Text(0.8297872340425532, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 10.2'),
#  Text(0.8382978723404255, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 10.1'),
#  Text(0.851063829787234, 0.3181818181818182, 'x[2] <= 97.65\nsquared_error = 0.002\nsamples = 2\nvalue = 9.95'),
#  Text(0.8468085106382979, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 9.9'),
#  Text(0.8553191489361702, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 10.0'),
#  Text(0.8638297872340426, 0.4090909090909091, 'x[0] <= 1.077\nsquared_error = 0.01\nsamples = 4\nvalue = 9.5'),
#  Text(0.8595744680851064, 0.3181818181818182, 'squared_error = 0.0\nsamples = 2\nvalue = 9.6'),
#  Text(0.8680851063829788, 0.3181818181818182, 'squared_error = -0.0\nsamples = 2\nvalue = 9.4'),
#  Text(0.9, 0.5909090909090909, 'x[0] <= 1.08\nsquared_error = 0.176\nsamples = 10\nvalue = 8.4'),
#  Text(0.8893617021276595, 0.5, 'x[0] <= 1.079\nsquared_error = 0.048\nsamples = 7\nvalue = 8.643'),
#  Text(0.8808510638297873, 0.4090909090909091, 'x[1] <= 86.15\nsquared_error = 0.009\nsamples = 3\nvalue = 8.867'),
#  Text(0.8765957446808511, 0.3181818181818182, 'squared_error = 0.0\nsamples = 2\nvalue = 8.8'),
#  Text(0.8851063829787233, 0.3181818181818182, 'squared_error = -0.0\nsamples = 1\nvalue = 9.0'),
#  Text(0.8978723404255319, 0.4090909090909091, 'x[4] <= 59.15\nsquared_error = 0.012\nsamples = 4\nvalue = 8.475'),
#  Text(0.8936170212765957, 0.3181818181818182, 'x[1] <= 83.4\nsquared_error = 0.002\nsamples = 3\nvalue = 8.533'),
#  Text(0.8893617021276595, 0.22727272727272727, 'squared_error = 0.0\nsamples = 2\nvalue = 8.5'),
#  Text(0.8978723404255319, 0.22727272727272727, 'squared_error = -0.0\nsamples = 1\nvalue = 8.6'),
#  Text(0.902127659574468, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 8.3'),
#  Text(0.9106382978723404, 0.5, 'x[0] <= 1.081\nsquared_error = 0.016\nsamples = 3\nvalue = 7.833'),
#  Text(0.9063829787234042, 0.4090909090909091, 'squared_error = 0.0\nsamples = 1\nvalue = 8.0'),
#  Text(0.9148936170212766, 0.4090909090909091, 'x[2] <= 94.35\nsquared_error = 0.002\nsamples = 2\nvalue = 7.75'),
#  Text(0.9106382978723404, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 7.7'),
#  Text(0.9191489361702128, 0.3181818181818182, 'squared_error = -0.0\nsamples = 1\nvalue = 7.8'),
#  Text(0.9670212765957447, 0.6818181818181818, 'x[1] <= 94.15\nsquared_error = 13.544\nsamples = 16\nvalue = 5.387'),
#  Text(0.9627659574468085, 0.5909090909090909, 'x[0] <= 1.089\nsquared_error = 4.185\nsamples = 15\nvalue = 4.587'),
#  Text(0.9425531914893617, 0.5, 'x[0] <= 1.085\nsquared_error = 0.262\nsamples = 8\nvalue = 6.175'),
#  Text(0.9319148936170213, 0.4090909090909091, 'x[4] <= 57.85\nsquared_error = 0.107\nsamples = 4\nvalue = 6.575'),
#  Text(0.9276595744680851, 0.3181818181818182, 'x[4] <= 52.0\nsquared_error = 0.02\nsamples = 3\nvalue = 6.4'),
#  Text(0.9234042553191489, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 6.6'),
#  Text(0.9319148936170213, 0.22727272727272727, 'squared_error = 0.0\nsamples = 2\nvalue = 6.3'),
#  Text(0.9361702127659575, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 7.1'),
#  Text(0.9531914893617022, 0.4090909090909091, 'x[2] <= 93.55\nsquared_error = 0.097\nsamples = 4\nvalue = 5.775'),
#  Text(0.9446808510638298, 0.3181818181818182, 'x[1] <= 80.5\nsquared_error = 0.04\nsamples = 2\nvalue = 5.5'),
#  Text(0.9404255319148936, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 5.3'),
#  Text(0.948936170212766, 0.22727272727272727, 'squared_error = -0.0\nsamples = 1\nvalue = 5.7'),
#  Text(0.9617021276595744, 0.3181818181818182, 'x[3] <= 100.65\nsquared_error = 0.002\nsamples = 2\nvalue = 6.05'),
#  Text(0.9574468085106383, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 6.1'),
#  Text(0.9659574468085106, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 6.0'),
#  Text(0.9829787234042553, 0.5, 'x[4] <= 50.05\nsquared_error = 2.491\nsamples = 7\nvalue = 2.771'),
#  Text(0.9744680851063829, 0.4090909090909091, 'x[4] <= 48.6\nsquared_error = 0.122\nsamples = 2\nvalue = 0.35'),
#  Text(0.9702127659574468, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(0.9787234042553191, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 0.7'),
#  Text(0.9914893617021276, 0.4090909090909091, 'x[0] <= 1.092\nsquared_error = 0.154\nsamples = 5\nvalue = 3.74'),
#  Text(0.9872340425531915, 0.3181818181818182, 'x[0] <= 1.091\nsquared_error = 0.022\nsamples = 4\nvalue = 3.925'),
#  Text(0.9829787234042553, 0.22727272727272727, 'x[3] <= 94.25\nsquared_error = 0.007\nsamples = 3\nvalue = 4.0'),
#  Text(0.9787234042553191, 0.13636363636363635, 'x[2] <= 85.5\nsquared_error = 0.002\nsamples = 2\nvalue = 3.95'),
#  Text(0.9744680851063829, 0.045454545454545456, 'squared_error = 0.0\nsamples = 1\nvalue = 4.0'),
#  Text(0.9829787234042553, 0.045454545454545456, 'squared_error = -0.0\nsamples = 1\nvalue = 3.9'),
#  Text(0.9872340425531915, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 4.1'),
#  Text(0.9914893617021276, 0.22727272727272727, 'squared_error = -0.0\nsamples = 1\nvalue = 3.7'),
#  Text(0.9957446808510638, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 3.0'),
#  Text(0.9712765957446808, 0.5909090909090909, 'squared_error = -0.0\nsamples = 1\nvalue = 17.4')]

# %%
path = reg.cost_complexity_pruning_path(X_train, y_train)
ccp_alpha = path.ccp_alphas

# %%
ccp_alpha
# Out:
# array([0.00000000e+00, 5.65606158e-16, 5.65606158e-16, 5.65606158e-16,
#        8.48409237e-16, 1.13121232e-15, 2.26242463e-15, 2.26242463e-15,
#        3.95924310e-15, 4.52484926e-15, 6.78727389e-15, 1.65837479e-05,
#        2.48756219e-05, 2.48756219e-05, 2.48756219e-05, 2.48756219e-05,
#        2.48756219e-05, 2.48756219e-05, 2.48756219e-05, 2.48756219e-05,
#        2.48756219e-05, 2.48756219e-05, 2.48756219e-05, 2.48756219e-05,
#        2.48756219e-05, 2.48756219e-05, 2.48756219e-05, 2.48756219e-05,
#        2.48756219e-05, 2.48756219e-05, 2.48756219e-05, 2.48756219e-05,
#        2.48756219e-05, 2.48756219e-05, 2.48756219e-05, 2.48756219e-05,
#        3.31674959e-05, 3.31674959e-05, 3.31674959e-05, 3.31674959e-05,
#        3.31674959e-05, 3.31674959e-05, 3.31674959e-05, 3.31674959e-05,
#        3.31674959e-05, 3.31674959e-05, 3.31674959e-05, 3.31674959e-05,
#        3.73134328e-05, 4.97512438e-05, 4.97512438e-05, 5.97014925e-05,
#        6.21890547e-05, 6.63349917e-05, 6.63349917e-05, 7.46268657e-05,
#        7.46268657e-05, 7.46268657e-05, 7.46268657e-05, 7.46268657e-05,
#        7.46268657e-05, 7.46268657e-05, 9.95024876e-05, 9.95024876e-05,
#        9.95024876e-05, 1.03648425e-04, 1.06135987e-04, 1.06135987e-04,
#        1.11940299e-04, 1.11940299e-04, 1.11940299e-04, 1.11940299e-04,
#        1.32669983e-04, 1.32669983e-04, 1.99004975e-04, 1.99004975e-04,
#        1.99004975e-04, 2.03150912e-04, 2.07296849e-04, 2.07296849e-04,
#        2.23880597e-04, 2.23880597e-04, 2.56574271e-04, 2.98507463e-04,
#        2.98507463e-04, 2.98507463e-04, 2.98507463e-04, 3.10945274e-04,
#        3.35820896e-04, 3.75977257e-04, 3.98009950e-04, 4.24543947e-04,
#        4.47761194e-04, 4.47761194e-04, 4.87562189e-04, 5.30679934e-04,
#        5.30679934e-04, 5.59701493e-04, 5.97014925e-04, 6.63349917e-04,
#        7.00663350e-04, 7.00663350e-04, 7.31343284e-04, 7.73987207e-04,
#        8.29187396e-04, 9.00852878e-04, 9.55223881e-04, 1.20895522e-03,
#        1.21890547e-03, 1.21890547e-03, 1.30833926e-03, 1.34328358e-03,
#        1.34328358e-03, 1.50497512e-03, 1.55472637e-03, 1.82835821e-03,
#        2.18933112e-03, 2.33208955e-03, 2.57995736e-03, 2.73868751e-03,
#        3.00995025e-03, 3.40547264e-03, 3.65671642e-03, 4.77611940e-03,
#        4.78571429e-03, 5.03731343e-03, 5.97636816e-03, 6.15166591e-03,
#        6.15967780e-03, 6.36815920e-03, 6.44989339e-03, 6.84671879e-03,
#        7.31343284e-03, 9.95024876e-03, 1.11728694e-02, 1.14843962e-02,
#        1.79163705e-02, 1.97202449e-02, 2.44813433e-02, 3.10558320e-02,
#        3.43301350e-02, 3.74200426e-02, 4.40329602e-02, 6.04256854e-02,
#        8.16780384e-02, 8.89036635e-02, 1.00331675e-01, 1.28948220e-01,
#        1.43228496e-01, 1.47502439e-01, 2.02115139e-01, 2.15164416e-01,
#        2.34029851e-01, 5.08585039e-01, 7.65771973e-01, 8.20903106e-01,
#        1.08130770e+00, 1.62736130e+00, 1.67955644e+00, 5.43776230e+00,
#        9.41560890e+00, 4.87117262e+01])

# %%
len(ccp_alpha)
# Out:
# 162

# %%
alphalist[1:5]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 alphalist[1:5]
#
# NameError: name 'alphalist' is not defined

# %%
alphalist = []
for i in range(len(ccp_alpha)):
    reg = DecisionTreeRegressor(ccp_alpha=ccp_alpha[i])
    reg.fit(X_train,y_train)
    alphalist.append(reg)

# %%
trainscore = [alphalist[i].score(X_train,y_train) for i in range(len(alphalist))]

testscore = [alphalist[i].score(X_test,y_test) for i in range(len(alphalist))]

plt.xlabel('alpha')
plt.ylabel('accuracy')
plt.plot(ccp_alpha, trainscore, marker = 'o', label = 'training' ,color = 'magenta', drawstyle = 'steps-post')
plt.plot(ccp_alpha,testscore, marker = '+', label = 'testing' , color = 'red', drawstyle = 'steps-post')
plt.legend()
plt.show()

# %%
# normal approach

clf = DecisionTreeRegressor(ccp_alpha = 1)
clf.fit(X_train,y_train)
y_pred = clf.predict(X_test)
print(f'Decision Tree Normal Apporch : {metrics.r2_score(y_test, y_pred)}')

rf = RandomForestRegressor(n_estimators=1000,ccp_alpha=1)
rf.fit(X_train, y_train)
y_pred_rf = rf.predict(X_test)
print(f'Random Forest Normal Approch : {metrics.r2_score(y_test,y_pred_rf)}')
# Out:
# Decision Tree Normal Apporch : 0.946801333794931
# Random Forest Normal Approch : 0.9786067732144899

# %% [markdown]
# # Hyperparameter Tuning

# %%
params = {
    'RandomFoest':{
        'model':RandomForestRegressor(),
        'params':{
            'n_estimators': [int(x) for x in np.linspace(start=1, stop=1200, num=10)],
            'criterion' : ["mse","mae"],
            'max_depth': [int(x) for x in np.linspace(start=1, stop=30, num=5)],
            'min_samples_split':[2,5,10,12],
            'min_samples_leaf':[2,5,10,12],
            'max_features' :['auto','sqrt'],
            'ccp_alpha':[1,2,2.5,3,3.5,4,5],
        }   
        
  },
    'D-tree':{
        'model':DecisionTreeRegressor(),
        'params':{
            'criterion':["mse","mae"],
            'splitter':['best','random'],
            'min_samples_split':[1,2,5,10,12],
            'min_samples_leaf':[1,2,5,10,12],
            'max_features' :['auto','sqrt'],
            'ccp_alpha':[1,2,2.5,3,3.5,4,5],
        }   

  },
    'SVM':{
         'model':SVR(),
         'params':{
             'C':[0.25,0.50,0.75,1.0],
             'tol':[1e-10, 1e-5, 1e-4, 0.025, 0.50, 0.75],
             'kernel':['linear', 'poly', 'rbf', 'sigmoid'],
             'max_iter':[int(x) for x in np.linspace(start=1, stop=250, num=10)],
         }
    }
}

# %%
scores = []
for modelname,mp in params.items():
    clf = RandomizedSearchCV(mp['model'], param_distributions=mp['params'],
                            cv=5, n_jobs=-1, n_iter=10, scoring='neg_mean_squared_error')
clf.fit(X_train, y_train)
scores.append({              
        'model_name':modelname,
        'best_score':clf.best_score_,
        'best_estimator':clf.best_estimator_
        
              })
# Out:
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=167).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(

# %%
scoresdf = pd.DataFrame(scores,columns=['model_name','best_score','best_estimator'])
scoresdf
# Out:
#   model_name  best_score                                best_estimator
# 0        SVM   -30.34766  SVR(kernel='poly', max_iter=167, tol=0.0001)

# %%
scores[0]['best_estimator']
# Out:
# SVR(kernel='poly', max_iter=167, tol=0.0001)

# %%
rf = scores[0]['best_estimstor']
rf.fit(X_train,y_train)

y_pred = rf.predict(X_test)

print(metrics.r2_score(y_test,y_pred))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 rf = scores[0]['best_estimstor']
#       2 rf.fit(X_train,y_train)
#       4 y_pred = rf.predict(X_test)
#
# KeyError: 'best_estimstor'

# %%
totrain
# Out:
#      Density  Abdomen  Chest    Hip  Thigh
# 0     1.0708     85.2   93.1   94.5   59.0
# 1     1.0853     83.0   93.6   98.7   58.7
# 2     1.0414     87.9   95.8   99.2   59.6
# 3     1.0751     86.4  101.8  101.2   60.1
# 4     1.0340    100.0   97.3  101.9   63.2
# ..       ...      ...    ...    ...    ...
# 247   1.0736     83.6   89.2   88.8   49.6
# 248   1.0236    105.0  108.5  104.5   59.6
# 249   1.0328    111.5  111.1  101.7   60.3
# 250   1.0399    101.3  108.3   97.8   56.0
# 251   1.0271    108.5  112.4  107.1   59.3
#
# [252 rows x 5 columns]

# %%
totrainlist = np.array(totrain)
predicted = []
for i in range(len(totrainlist)):
    predicted.append(rf.predict([totrainlist[i]]))

totrain['Actual Result'] = test
totrain['Predicted Result'] = np.array(predicted) 
totrain
# Out:
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_24668\1479468740.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   totrain['Actual Result'] = test
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_24668\1479468740.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   totrain['Predicted Result'] = np.array(predicted)
#      Density  Abdomen  Chest    Hip  Thigh  Actual Result  Predicted Result
# 0     1.0708     85.2   93.1   94.5   59.0           12.3         12.794962
# 1     1.0853     83.0   93.6   98.7   58.7            6.1          6.951902
# 2     1.0414     87.9   95.8   99.2   59.6           25.3         25.074708
# 3     1.0751     86.4  101.8  101.2   60.1           10.4          9.494652
# 4     1.0340    100.0   97.3  101.9   63.2           28.7         30.180086
# ..       ...      ...    ...    ...    ...            ...               ...
# 247   1.0736     83.6   89.2   88.8   49.6           11.0         10.265122
# 248   1.0236    105.0  108.5  104.5   59.6           33.6         31.520243
# 249   1.0328    111.5  111.1  101.7   60.3           29.3         30.384194
# 250   1.0399    101.3  108.3   97.8   56.0           26.0         25.263256
# 251   1.0271    108.5  112.4  107.1   59.3           31.9         31.326755
#
# [252 rows x 7 columns]

# %%
sn.distplot(totrain['Actual Result'],label='Actual Result',hist=False,color='magenta')
sn.distplot(totrain['Predicted Result'],label='Predicted Result',hist=False,color='red')
plt.legend()
plt.plot()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_24668\522113489.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(totrain['Actual Result'],label='Actual Result',hist=False,color='magenta')
# C:\Users\ASUS\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_24668\522113489.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(totrain['Predicted Result'],label='Predicted Result',hist=False,color='red')
# C:\Users\ASUS\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# []

# %%
# saving the model

import pickle
file =open('bodyfatmodel.pkl','wb')
pickle.dump(rf,file)
file.close()
